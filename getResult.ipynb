# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def showFeatures(key,w):
    print(w)
    fig = plt.figure(figsize=(8, 8))
    fig.suptitle(key, fontsize=16)
    ax = fig.add_axes([0,0,1,1])
    ax.bar([str(i) for i in range(len(w))],[i for i in w])
    plt.show()

# %%
def result_stamp_first(stamp, params):
  dict_list = params.items()
  for k, v in dict_list:
    new_key = stamp+"_"+k
    params[new_key] = v
    del params[k]
  return params

# %%
import json
big_d = {}
f = open("resultFS_breast.txt", "r")
content = f.read()
lst = content.split("\n")
#print(lst)
for i in lst:
  if i[:4] == "{'sh" or i[:4] == "{'te" :
    #print(i)
    i_trimmed = i[1:-1]
    #print(i_trimmed)
    for j in i_trimmed.split(", '"):
      tup = j.split(":")
      key = tup[0].strip()[:-1]
      #print(tup)
      if key not in big_d.keys():
        big_d[key] = [tup[1].strip()]
      else:
        big_d[key].append(tup[1].strip())

#print(big_d)
del big_d["'shape"]
import pprint

#big_d = result_stamp_first("synth",big_d)

#pprint.pprint(big_d)
locals().update(big_d)
pprint.pprint(big_d)
title = "breast"
###Score_model = [4x]
##Score_model_red = [100,mid, 75,50]
###Stab_model = [100%,50,mid]
##Score_model_stamp = [score11,score12,score21,score22,..] len=10
###Score_model_red_stamp = [100,75,100,75,100,75,..] len=10
###Score_model_stab_stamp = [100,mid,100,mid,..] len=10
# Out:
# {"'shapel1": ['(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)'],
#  "'shapel2": ['(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)'],
#  "'shapel3": ['(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)',
#               '(380, 30)'],
#  "'shapethreshold": ['(380, 30)',
#                      '(380, 30)',
#                      '(380, 30)',
# ...

# %%
#STAB
#L1SCORE
#L1 STAB
#L2 SCORE
#L2 STAB
#L3 STAB
#L3 SCORE
#THRES SCORE
#THRES STAB
print(test_bcr_full_neuralFSl2l2)
# Out:
# ['0.9724137931034482', '0.9724137931034482', '0.9896551724137931', '0.967682437850842', '0.9896551724137931', '0.9793103448275862', '0.9849238171611868', '0.9827586206896552', '0.9780272654370489', '0.9745789895749799']

# %%
print("Model Scores")
print(test_bcr_full_neuralFS)
print("Mean NeuralFS", np.mean([float(i) for i in test_bcr_full_neuralFS]))
print("Mean PairWise", np.mean([float(i) for i in test_bcr_full_pairwise]))
print("Mean Regularized", np.mean([float(i) for i in test_bcr_full_regularized]))
print("Mean Baseline", np.mean([float(i) for i in test_bcr_full_baseline]))
print("Mean CancelOut", np.mean([float(i) for i in test_bcr_full_cancelOut]))
'''
print("100% of feature ranking")
print("Mean NeuralFS", np.mean(test_bcr_baseline_reduced_from_neuralFS[0])
print("Mean PairWise", np.mean(test_bcr_baseline_reduced_from_pairwise[0])
print("Mean Regularized", np.mean(test_bcr_baseline_reduced_from_regularized[0])
print("Mean Baseline", np.mean(test_bcr_baseline_reduced_from_baseline[0])
print("Mean CancelOut", np.mean(test_bcr_baseline_reduced_from_cancelOut[0])
'''
print("\n75% of feature ranking")
print("Mean NeuralFS", test_bcr_baseline_reduced_from_neuralFS[1])
print("Mean PairWise", test_bcr_baseline_reduced_from_pairwise[1])
print("Mean Regularized", test_bcr_baseline_reduced_from_regularized[1])
print("Mean Baseline", test_bcr_baseline_reduced_from_baseline[1])
print("Mean CancelOut", test_bcr_baseline_reduced_from_cancelOut[1])
print("Mean Filter", test_bcr_baseline_reduced_from_filter[1])

print("\n50% of feature ranking")
print("Mean NeuralFS", test_bcr_baseline_reduced_from_neuralFS[2])
print("Mean PairWise", test_bcr_baseline_reduced_from_pairwise[2])
print("Mean Regularized", test_bcr_baseline_reduced_from_regularized[2])
print("Mean Baseline", test_bcr_baseline_reduced_from_baseline[2])
print("Mean CancelOut", test_bcr_baseline_reduced_from_cancelOut[2])
print("Mean Filter", test_bcr_baseline_reduced_from_filter[2])

print("\nMiddle of feature ranking")
print("Mean NeuralFS", test_bcr_baseline_reduced_from_neuralFS[3])
print("Mean PairWise", test_bcr_baseline_reduced_from_pairwise[3])
print("Mean Regularized", test_bcr_baseline_reduced_from_regularized[3])
print("Mean Baseline", test_bcr_baseline_reduced_from_baseline[3])
print("Mean CancelOut", test_bcr_baseline_reduced_from_cancelOut[3])
print("Mean Filter", test_bcr_baseline_reduced_from_filter[3])


print("\nStability 100% of feature ranking")
print("Mean NeuralFS", stab_neuralFS[0])
print("Mean PairWise", stab_pairwise[0])
print("Mean Regularized", stab_regularized[0])
print("Mean Baseline", stab_baseline[0])
print("Mean CancelOut", stab_cancelOut[0])


print("\nStability 50% of feature ranking")
print("Mean NeuralFS", stab_neuralFS[1])
print("Mean PairWise", stab_pairwise[1])
print("Mean Regularized", stab_regularized[1])
print("Mean Baseline", stab_baseline[1])
print("Mean CancelOut", stab_cancelOut[1])

print("\nStability Middle of feature ranking")
print("Mean NeuralFS", stab_neuralFS[2])
print("Mean PairWise", stab_pairwise[2])
print("Mean Regularized", stab_regularized[2])
print("Mean Baseline", stab_baseline[2])
print("Mean CancelOut", stab_cancelOut[2])
# Out:
# Model Scores
# ['0.971130713712911', '0.9793103448275862', '0.9862068965517241', '0.9758620689655173']
# Mean NeuralFS 0.9781275060144345
# Mean PairWise 0.9609061748195671
# Mean Regularized 0.967682437850842
# Mean Baseline 0.9732758620689654
# Mean CancelOut 0.9732758620689654
#
# 75% of feature ranking
# Mean NeuralFS 0.9780272654370489
# Mean PairWise 0.9758620689655173
# Mean Regularized 0.9435445068163593
# Mean Baseline 0.9551724137931035
# Mean CancelOut 0.9642341619887731
# Mean Filter 0.9538893344025661
#
# 50% of feature ranking
# Mean NeuralFS 0.9758620689655173
# Mean PairWise 0.9435445068163593
# Mean Regularized 0.960785886126704
# Mean Baseline 0.9275862068965517
# Mean CancelOut 0.945709703287891
# Mean Filter 0.9478748997594226
#
# Middle of feature ranking
# Mean NeuralFS 0.9629510825982357
# Mean PairWise 0.9780272654370489
# Mean Regularized 0.9551724137931035
# Mean Baseline 0.971130713712911
# Mean CancelOut 0.9431435445068164
# Mean Filter 0.9448275862068966
# ...

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(7, 7))

plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_full_regularizedl1[i]),3) for i in range(0,len(test_bcr_full_regularizedl1),2)], 'ro-', label='Regularized')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_full_pairwisel1[i]),3) for i in range(0,len(test_bcr_full_pairwisel1),2)], 'bo-',  label='Pairwise')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_full_cancelOutl1[i]),3) for i in range(0,len(test_bcr_full_cancelOutl1),2)], 'yo-', label='CancelOut')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_baseline_reduced_from_regularizedl1[i]),3) for i in range(1,len(test_bcr_baseline_reduced_from_regularizedl1),2)], 'ro--', label='Regularized reduced')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_baseline_reduced_from_pairwisel1[i]),3) for i in range(1,len(test_bcr_baseline_reduced_from_pairwisel1),2)], 'bo--',  label='Pairwise reduced')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_baseline_reduced_from_cancelOutl1[i]),3) for i in range(1,len(test_bcr_baseline_reduced_from_cancelOutl1),2)], 'yo--', label='CancelOut reduced')

plt.ylabel('BCR')
plt.legend()
plt.xlabel('L1 penalty')
plt.title('Influence of L1 regularization for BCR on '+title+" dataset")

plt.show()
# Out:
# ['0.9862068965517241', '0.9620689655172414', '0.9547714514835606', '0.9698476343223736', '0.9069767441860466', '0.9186046511627908', '0.9186046511627908', '0.9616680032076985', '0.9418604651162791', '0.9418604651162791', '0.9724137931034482', '0.9793103448275862', '0.9560545308740979', '0.9526062550120289', '0.9186046511627908', '0.9069767441860466', '0.9069767441860466', '0.9069767441860466', '0.9418604651162791', '0.9500400962309543', '0.9793103448275862', '0.9724137931034482']

# %%
import matplotlib.pyplot as plt
print(test_bcr_full_regularizedl1)
plt.subplots(figsize=(7, 7))

plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_regularized_l1[i]),3) for i in range(0,len(stab_regularized_l1),2)], 'ro-', label='Regularized 100%')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_pairwise_l1[i]),3) for i in range(0,len(stab_pairwise_l1),2)], 'bo-',  label='Pairwise 100%')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_cancelOut_l1[i]),3) for i in range(0,len(stab_cancelOut_l1),2)], 'yo-', label='CancelOut 100%')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_regularized_l1[i]),3) for i in range(1,len(stab_regularized_l1),2)], 'ro--', label='Regularized Mid')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_pairwise_l1[i]),3) for i in range(1,len(stab_pairwise_l1),2)], 'bo--',  label='Pairwise Mid')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_cancelOut_l1[i]),3) for i in range(1,len(stab_cancelOut_l1),2)], 'yo--', label='CancelOut Mid')
plt.ylabel('Jaccard or Kunsheva index')
plt.legend()
plt.xlabel('L1 penalty')
plt.title('Influence of L1 regularization on stability on '+title)

plt.show()
# Out:
# ['0.9862068965517241', '0.9620689655172414', '0.9547714514835606', '0.9698476343223736', '0.9069767441860466', '0.9186046511627908', '0.9186046511627908', '0.9616680032076985', '0.9500400962309543', '0.9418604651162791']

# %%
plt.subplots(figsize=(7, 7))

plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_full_neuralFSl2[i]),3) for i in range(0,len(test_bcr_full_neuralFSl2),2)], 'ro-', label='NeuralFS')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_full_pairwisel2[i]),3) for i in range(0,len(test_bcr_full_pairwisel2),2)], 'bo-',  label='Pairwise')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_full_cancelOutl2[i]),3) for i in range(0,len(test_bcr_full_cancelOutl2),2)], 'yo-', label='CancelOut')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_baseline_reduced_from_neuralFSl2[i]),3) for i in range(1,len(test_bcr_baseline_reduced_from_neuralFSl2),2)], 'ro--', label='NeuralFS reduced')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_baseline_reduced_from_pairwisel2[i]),3) for i in range(1,len(test_bcr_baseline_reduced_from_pairwisel2),2)], 'bo--',  label='Pairwise reduced')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_baseline_reduced_from_cancelOutl2[i]),3) for i in range(1,len(test_bcr_baseline_reduced_from_cancelOutl2),2)], 'yo--', label='CancelOut reduced')

plt.ylabel('BCR')
plt.legend()
plt.xlabel('L2 penalty')
plt.title('Influence of L2 regularization for BCR on '+title+" dataset")

plt.show()

# %%
import matplotlib.pyplot as plt
print(test_bcr_full_neuralFSl2)
plt.subplots(figsize=(7, 7))

plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_neuralFS_l2[i]),3) for i in range(0,len(stab_neuralFS_l2),2)], 'go-', label='Regularized 100%')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_pairwise_l2[i]),3) for i in range(0,len(stab_pairwise_l2),2)], 'bo-',  label='Pairwise 100%')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_cancelOut_l2[i]),3) for i in range(0,len(stab_cancelOut_l2),2)], 'yo-', label='CancelOut 100%')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_neuralFS_l2[i]),3) for i in range(1,len(stab_neuralFS_l2),2)], 'go--', label='Regularized Mid')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_pairwise_l2[i]),3) for i in range(1,len(stab_pairwise_l2),2)], 'bo--',  label='Pairwise Mid')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_cancelOut_l2[i]),3) for i in range(1,len(stab_cancelOut_l2),2)], 'yo--', label='CancelOut Mid')
plt.ylabel('Jaccard or Kunsheva index')
plt.legend()
plt.xlabel('L2 penalty')
plt.title('Influence of L2 regularization on stability on '+title)

plt.show()
# Out:
# ['0.9724137931034482', '0.9724137931034482', '0.9896551724137931', '0.967682437850842', '0.9896551724137931', '0.9793103448275862', '0.9849238171611868', '0.9827586206896552', '0.9780272654370489', '0.9745789895749799']

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(7, 7))

plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_full_regularizedl3[i]),3) for i in range(0,len(test_bcr_full_regularizedl3),2)], 'ro-', label='Regularized')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_full_pairwisel3[i]),3) for i in range(0,len(test_bcr_full_pairwisel3),2)], 'bo-',  label='Pairwise')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_full_cancelOutl3[i]),3) for i in range(0,len(test_bcr_full_cancelOutl3),2)], 'yo-', label='CancelOut')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_baseline_reduced_from_regularizedl3[i]),3) for i in range(1,len(test_bcr_baseline_reduced_from_regularizedl3),2)], 'ro--', label='Regularized reduced')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_baseline_reduced_from_pairwisel3[i]),3) for i in range(1,len(test_bcr_baseline_reduced_from_pairwisel3),2)], 'bo--',  label='Pairwise reduced')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(test_bcr_baseline_reduced_from_cancelOutl3[i]),3) for i in range(1,len(test_bcr_baseline_reduced_from_cancelOutl3),2)], 'yo--', label='CancelOut reduced')

plt.ylabel('BCR')
plt.legend()
plt.xlabel('L1 penalty')
plt.title('Influence of L3 regularization for BCR on '+title+" dataset")

plt.show()

# %%
import matplotlib.pyplot as plt
print(test_bcr_full_regularizedl3)
plt.subplots(figsize=(7, 7))

plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_regularized_l3[i]),3) for i in range(0,len(stab_regularized_l3),2)], 'ro-', label='Regularized 100%')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_pairwise_l3[i]),3) for i in range(0,len(stab_pairwise_l3),2)], 'bo-',  label='Pairwise 100%')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_cancelOut_l3[i]),3) for i in range(0,len(stab_cancelOut_l3),2)], 'yo-', label='CancelOut 100%')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_regularized_l3[i]),3) for i in range(1,len(stab_regularized_l3),2)], 'ro--', label='Regularized Mid')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_pairwise_l3[i]),3) for i in range(1,len(stab_pairwise_l3),2)], 'bo--',  label='Pairwise Mid')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_cancelOut_l3[i]),3) for i in range(1,len(stab_cancelOut_l3),2)], 'yo--', label='CancelOut Mid')
plt.ylabel('Jaccard or Kunsheva index')
plt.legend()
plt.xlabel('L3 penalty')
plt.title('Influence of L3 regularization on stability on '+title)

plt.show()
# Out:
# ['0.9642341619887731', '0.9689655172413794', '0.9896551724137931', '0.9780272654370489', '0.9793103448275862', '0.967682437850842', '0.9827586206896552', '0.9689655172413794', '0.9642341619887731', '0.9745789895749799']

# %%
print(test_bcr_full_regularizedl3)
plt.subplots(figsize=(7, 7))
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_neuralFS_threshold[i]),3) for i in range(0,len(stab_neuralFS_l2),2)], 'go-', label='Regularized 100%')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_neuralFS_threshold[i]),3) for i in range(1,len(stab_neuralFS_l2),2)], 'go--', label='Regularized Mid')
plt.ylabel('BCR')
plt.legend()
plt.xlabel('Threshold penalty')
plt.title('Influence of threshold regularization for BCR on '+title+" dataset")

plt.show()
# Out:
# ['0.9642341619887731', '0.9689655172413794', '0.9896551724137931', '0.9780272654370489', '0.9793103448275862', '0.967682437850842', '0.9827586206896552', '0.9689655172413794', '0.9642341619887731', '0.9745789895749799']

# %%
plt.subplots(figsize=(7, 7))
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_neuralFS_threshold[i]),3) for i in range(0,len(stab_neuralFS_threshold),2)], 'go-', label='Regularized 100%')
plt.plot([0.01,0.1,0.3,0.5,0.8],[round(float(stab_neuralFS_threshold[i]),3) for i in range(1,len(stab_neuralFS_threshold),2)], 'go--', label='Regularized Mid')
plt.ylabel('Jaccard or Kunsheva index')
plt.legend()
plt.xlabel('Threshold penalty')
plt.title('Influence of threshold regularization on stability on '+title)
# Out:
# Text(0.5, 1.0, 'Influence of threshold regularization on stability on breast')
